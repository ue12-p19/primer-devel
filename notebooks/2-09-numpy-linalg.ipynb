# %% [markdown]
# <div class="licence">
# <span>Licence CC BY-NC-ND</span>
# <span>Valérie Roy</span>
# <span><img src="media/ensmp-25-alpha.png" /></span>
# </div>

# %% [markdown]
# ## 10) linear algebra

# %% [markdown]
#    - with *numpy* you **manipulate** **vectors** and **matrices**
#    - https://docs.scipy.org/doc/numpy/reference/routines.linalg.html

# %% [markdown]
# ### a) vector, matrix multiplication with *numpy.dot*
#
# https://stackoverflow.com/questions/3890621/how-does-multiplication-differ-for-numpy-matrix-vs-array-classes

# %%
import numpy as np

# %% [markdown]
# ##### we can multiply **two vectors** (**inner product** of vectors)

# %%
v = np.array([1, 2, 3])
w = np.array([4, 5, 6])

# %%
np.dot(v, w)

# %%
v.dot(w)

# %% [markdown]
#    - be careful *** is **an element by element** product

# %%
v*w

# %% [markdown]
# ##### we can multiply a **matrix** by a **vector**

# %% [markdown]
#    - $a$ is a $(3 \times 4)$ matrix

# %%
a = np.arange(1, 13).reshape(3, 4)
a

# %% [markdown]
#    - the **vector** must have $4$ rows

# %%
b = np.arange(11, 15).reshape(4, 1)
b

# %%
print(a, '.\n', b)

# %%
np.dot(a, b)

# %% [markdown]
#    - another way to call *numpy.dot*

# %%
a.dot(b)

# %% [markdown]
#    - be careful $*$ is the **element-by-element** multiplication

# %%
a*a

# %% [markdown]
# ##### we can multiply two **matrices**

# %% [markdown]
#    - $a$ is a $(3 \times 4)$ matrix

# %%
b = np.arange(11, 23).reshape(4, 3)
b

# %% [markdown]
#    - the second **matrix** must be  $(4 \times 3)$

# %%
np.dot(a, b)

# %% [markdown]
#    - the method exists also on the *numpy* **object**

# %%
a.dot(b)

# %% [markdown]
# *numpy.vdot*
#    - it returns the **dot product** of two **vectors**
#    - should **only** be used for **vectors**
#    - handles **multidimensional** arrays by **flattening** its **input** arrays

# %%
a = np.arange(1, 13).reshape(4, 3)

b = np.arange(11, 23).reshape(3, 4)

print(np.vdot(a, b))

# %% [markdown]
#    - to obtain the same with *numpy.dot*
#    -you must **flatten** the matrices

# %%
np.dot(a.flatten(), b.flatten())

# %% [markdown]
# *numpy.dot* return a *numpy.ndarray*

# %% [markdown]
# see also *numpy.tensordot*, *numpy.inner*, *numpy.outer*, ...

# %% [markdown]
# ### a) matrix multiplication with *numpy.matmul*

# %%
np.matmul(a, b)

# %%
b = np.array([[10, 20],
              [30, 40]])
b

# %% [markdown]
# *numpy.matmul* return a *numpy.ndarray*

# %% [markdown]
#    - in this example *numpy.matmul* and *numpy.dot* return the **same** result

# %% [markdown]
# XXX UNDO ME XXX
# je transforme cette cellule de code a markdown pour pouvoir générer tout le html
# np.matmul(a, b) == np.dot(a, b)

# %% [markdown]
#    - but it not always the same
#    - the functions are **different** see the help
#    - or see https://stackoverflow.com/questions/34142485/difference-between-numpy-dot-and-python-3-5-matrix-multiplication

# %% [markdown]
# ### matrix transposition

# %%
a.T

# %%
np.transpose(a)

# %% [markdown]
# ### other mathematic functions

# %% [markdown]
# | methods           |   behavior |
# |-----------------|--------|
# | *numpy.linalg.det* | determinant |
# | *numpy.linalg.inv* | inversion |
# | *numpy.linalg.eig* | eigen values |
# | *numpy.linalg..solve* | solving equation system |
# | *numpy.eye*       |identity matrix |
# | *numpy.diag*      | extract diagonal|
# | *numpy.diag*      | build diagonal matrix |
# | **...**           | ...|

# %% [markdown]
# ### norm

# %%
a = np.arange(1, 16).reshape(3, 5)
a

# %% [markdown]
#    - **2-morm**
#    - $\displaystyle \left\|{\boldsymbol {x}}\right\|_{2}={\sqrt {x_{1}^{2}+\cdots +x_{n}^{2}}}$

# %%
np.linalg.norm(a)

# %%
np.sqrt(np.sum(np.power(a.ravel(), 2)))

# %% [markdown]
#    - **2-norm** on **rows**

# %%
np.linalg.norm(a, axis=0)

# %%
np.sqrt(np.sum(np.power(a, 2), axis=0))

# %% [markdown]
#    - **2-norm** on **columns**

# %%
np.linalg.norm(a, axis=1)

# %%
np.sqrt(np.sum(np.power(a, 2), axis=1))

# %% [markdown]
# ### determinant

# %%
b = np.random.random(size=(3, 3))
b

# %%
np.linalg.det(b)

# %% [markdown]
# ### diagonal

# %% [markdown]
#    - return the diagonal

# %%
np.diag(b)

# %% [markdown]
#    - create a diagonal matrix

# %%
np.diag([1, 2, 3])

# %% [markdown]
# ### trace

# %% [markdown]
#    - the sum along the **diagonal** of the arrays

# %%
b = np.arange(12).reshape(3, 4)
b

# %%
np.trace(b)

# %% [markdown]
# ### inversion

# %%
b = np.random.random(size=(3, 3))
b

# %% [markdown]
#    - $b^{-1}b=I$
#    - (**almost equal** for computer-numbers)

# %%
np.isclose(  np.dot(np.linalg.inv(b), b),   np.identity(b.shape[0]) )

# %% [markdown]
# ### eignen values

# %% [markdown]
#    - $f(v) = \lambda v$
#    - $M v = \lambda v$

# %%
M = np.random.random(size=(3, 3))
l, v = np.linalg.eig(M)  # eigen_values, eigen_vectors
l, v

# %% [markdown]
#    - $M v = \lambda v$

# %%
np.isclose(   np.dot(M, v[:, 0]),  l[0]* v[:, 0] )

# %% [markdown]
#    - $(M - \lambda I) = 0$

# %%
np.isclose(    np.dot(M - l[0]*np.identity(3), v[:, 0]),   np.zeros(3))

# %% [markdown]
# ### solve

# %% [markdown]
# a x = b

# %%
A = np.random.random(size=(3, 3))
b = [1, 2, 3]

# %%
x = np.linalg.solve(A, b) # A x = b
x

# %%
np.isclose( np.dot(A, x), b)
